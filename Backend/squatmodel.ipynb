# %%
import os
import cv2
import numpy as np
import mediapipe as mp
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers, callbacks
from tqdm import tqdm
from tqdm.keras import TqdmCallback
import joblib
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
# Out:
# 2.20.0

# %%
target_dir = 'squat'

for dirname, _, filenames in os.walk(target_dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# squat\squat_10.mp4
# squat\squat_11.mp4
# squat\squat_12.mp4
# squat\squat_13.mp4
# squat\squat_14.mp4
# squat\squat_15.mp4
# squat\squat_16.mp4
# squat\squat_17.mp4
# squat\squat_18.mp4
# squat\squat_19.mp4
# squat\squat_2.MOV
# squat\squat_20.mp4
# squat\squat_21.mp4
# squat\squat_22.mp4
# squat\squat_23.mp4
# squat\squat_24.mp4
# squat\squat_25.mp4
# squat\squat_26.mp4
# squat\squat_27.mp4
# squat\squat_28.mp4
# squat\squat_3.MOV
# squat\squat_4.MOV
# squat\squat_5.MOV
# squat\squat_6.MOV
# squat\squat_7.mp4
# squat\squat_8.mp4
# squat\squat_9.mp4

# %% [markdown]
# # Pose Setup

# %%
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, model_complexity=1, enable_segmentation=False)

# %% [markdown]
# # Feature Extraction & Keypoint

# %% [markdown]
# ##### Function for extract keypoints from the video

# %%
def extract_keypoints(path):
    cap = cv2.VideoCapture(path)
    keypts_all = []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        res = pose.process(img_rgb)
        if res.pose_landmarks:
            keypts = np.array([[lm.x, lm.y, lm.z] for lm in res.pose_landmarks.landmark])
            keypts_all.append(keypts)
    cap.release()
    return np.array(keypts_all)

# %% [markdown]
# ##### Calculate Angle

# %%
def calculate_angle(A, B, C):
    vba = A - B
    vbc = C - B

    dot_product = np.dot(vba,vbc)
    magnitude = np.linalg.norm(vba) * np.linalg.norm(vbc)
    cos_angle = dot_product / (magnitude + 1e-6)
    angle_rad = np.arccos(np.clip(cos_angle, -1.0, 1.0))
    return np.degrees(angle_rad)

# %% [markdown]
# ##### Feature Extraction

# %%
def extract_features(keypts_seq):
    if len(keypts_seq) == 0:
        return np.zeros(30)

    try:
        left_knee = [calculate_angle(f[23], f[25], f[27]) for f in keypts_seq]
        right_knee = [calculate_angle(f[24], f[26], f[28]) for f in keypts_seq]
        left_hip = [calculate_angle(f[11], f[23], f[25]) for f in keypts_seq]
        right_hip = [calculate_angle(f[12], f[24], f[26]) for f in keypts_seq]
        left_ankle = [calculate_angle(f[25], f[27], f[31]) for f in keypts_seq]
        right_ankle = [calculate_angle(f[26], f[28], f[32]) for f in keypts_seq]
    except Exception:
        return np.zeros(30)
    features = []
    angle_sequences = [left_knee, right_knee, left_hip, right_hip, left_ankle, right_ankle]
    
    for seq in angle_sequences:
        features.extend([np.mean(seq), np.std(seq), np.min(seq), np.max(seq), np.ptp(seq)])

    return np.array(features)

# %%
def extract_features_video(path):
    keypts_all = extract_keypoints(path)
    return extract_features(keypts_all)

# %% [markdown]
# # 1. Data Preparation

# %%
base_dir = "squat" 
output_dir = "models/squat-models" 
os.makedirs(output_dir, exist_ok=True)

# %%
print(f"Isi direktori {base_dir}: {os.listdir(base_dir)[:5]}...")
# Out:
# Isi direktori squat: ['squat_10.mp4', 'squat_11.mp4', 'squat_12.mp4', 'squat_13.mp4', 'squat_14.mp4']...

# %%
features = []
for vid in tqdm(os.listdir(base_dir)):
    if not (vid.lower().endswith(".mp4") or vid.lower().endswith(".mov")): continue
    video_path = os.path.join(base_dir, vid)    
    feat = extract_features_video(video_path) 
    if np.allclose(feat, 0): continue
    features.append(feat)
# Out:
# 100%|██████████| 27/27 [03:43<00:00,  8.29s/it]

# %%
x = np.vstack(features)
print(f"Feature sample: {x.shape[0]}")
# Out:
# Feature sample: 27

# %% [markdown]
# # 2. Normalization

# %%
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)
joblib.dump(scaler, os.path.join(output_dir, "squat_scaler.pkl"))
# Out:
# ['models/squat-models\\squat_scaler.pkl']

# %% [markdown]
# # 3. Model Building

# %%
inputs = layers.Input(shape=(x_scaled.shape[1], ))
x = layers.GaussianNoise(0.02)(inputs)
x = layers.Dense(64, activation="relu", kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.Dense(32, activation="relu", kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.Dropout(0.1)(x)
x = layers.Dense(16, activation="relu", kernel_regularizer=regularizers.l2(1e-4))(x) 
x = layers.Dense(32, activation="relu")(x)
x = layers.Dense(64, activation="relu")(x)
outputs = layers.Dense(x_scaled.shape[1], activation="linear")(x)

# %%
autoencoder = models.Model(inputs, outputs)
autoencoder.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise_1                │ (None, 30)             │             0 │
# │ (GaussianNoise)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         1,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 30)             │         1,950 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,198 (35.93 KB)
#  Trainable params: 9,198 (35.93 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss="mse")

# %% [markdown]
# # 4. Model Training

# %% [markdown]
# **- early_stopping** digunakan <br>
# **- reduce_lr** digunakan untuk menurunkan learning rate secara otomatis ketika model sudah tidak membaik lagi.

# %%
early_stopping = callbacks.EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True, verbose=0)
reduce_lr = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=6, min_lr=1e-6, verbose=0)

# %%
history = autoencoder.fit(x_scaled, x_scaled, epochs=200, batch_size=8, validation_split=0.2, callbacks=[early_stopping, reduce_lr], verbose=1)
# Out:
# Epoch 1/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.3032 - val_loss: 0.3307 - learning_rate: 0.0010
# Epoch 2/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2762 - val_loss: 0.2924 - learning_rate: 0.0010
# Epoch 3/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2486 - val_loss: 0.2522 - learning_rate: 0.0010
# Epoch 4/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2147 - val_loss: 0.2132 - learning_rate: 0.0010
# Epoch 5/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1841 - val_loss: 0.1796 - learning_rate: 0.0010
# Epoch 6/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1638 - val_loss: 0.1514 - learning_rate: 0.0010
# Epoch 7/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1431 - val_loss: 0.1246 - learning_rate: 0.0010
# Epoch 8/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1222 - val_loss: 0.1019 - learning_rate: 0.0010
# Epoch 9/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1080 - val_loss: 0.0856 - learning_rate: 0.0010
# Epoch 10/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0966 - val_loss: 0.0732 - learning_rate: 0.0010
# Epoch 11/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0885 - val_loss: 0.0635 - learning_rate: 0.0010
# Epoch 12/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0794 - val_loss: 0.0578 - learning_rate: 0.0010
# Epoch 13/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0745 - val_loss: 0.0558 - learning_rate: 0.0010
# Epoch 14/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0711 - val_loss: 0.0549 - learning_rate: 0.0010
# Epoch 15/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0675 - val_loss: 0.0548 - learning_rate: 0.0010
# Epoch 16/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0668 - val_loss: 0.0538 - learning_rate: 0.0010
# Epoch 17/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0673 - val_loss: 0.0524 - learning_rate: 0.0010
# Epoch 18/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0641 - val_loss: 0.0506 - learning_rate: 0.0010
# Epoch 19/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0649 - val_loss: 0.0496 - learning_rate: 0.0010
# Epoch 20/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0646 - val_loss: 0.0491 - learning_rate: 0.0010
# Epoch 21/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0606 - val_loss: 0.0493 - learning_rate: 0.0010
# Epoch 22/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0637 - val_loss: 0.0488 - learning_rate: 0.0010
# Epoch 23/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0619 - val_loss: 0.0485 - learning_rate: 0.0010
# Epoch 24/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0605 - val_loss: 0.0480 - learning_rate: 0.0010
# Epoch 25/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0583 - val_loss: 0.0469 - learning_rate: 0.0010
# Epoch 26/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0600 - val_loss: 0.0457 - learning_rate: 0.0010
# Epoch 27/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0568 - val_loss: 0.0458 - learning_rate: 0.0010
# Epoch 28/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0584 - val_loss: 0.0455 - learning_rate: 0.0010
# Epoch 29/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0554 - val_loss: 0.0452 - learning_rate: 0.0010
# Epoch 30/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0530 - val_loss: 0.0451 - learning_rate: 0.0010
# Epoch 31/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0568 - val_loss: 0.0459 - learning_rate: 0.0010
# Epoch 32/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0525 - val_loss: 0.0458 - learning_rate: 0.0010
# Epoch 33/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0507 - val_loss: 0.0448 - learning_rate: 0.0010
# Epoch 34/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0537 - val_loss: 0.0445 - learning_rate: 0.0010
# Epoch 35/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0503 - val_loss: 0.0443 - learning_rate: 0.0010
# Epoch 36/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0477 - val_loss: 0.0442 - learning_rate: 0.0010
# Epoch 37/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0500 - val_loss: 0.0447 - learning_rate: 0.0010
# Epoch 38/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0493 - val_loss: 0.0421 - learning_rate: 0.0010
# Epoch 39/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0508 - val_loss: 0.0428 - learning_rate: 0.0010
# Epoch 40/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0480 - val_loss: 0.0410 - learning_rate: 0.0010
# Epoch 41/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0461 - val_loss: 0.0416 - learning_rate: 0.0010
# Epoch 42/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0452 - val_loss: 0.0426 - learning_rate: 0.0010
# Epoch 43/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0449 - val_loss: 0.0423 - learning_rate: 0.0010
# Epoch 44/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0430 - val_loss: 0.0418 - learning_rate: 0.0010
# Epoch 45/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0404 - val_loss: 0.0415 - learning_rate: 0.0010
# Epoch 46/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0412 - val_loss: 0.0411 - learning_rate: 0.0010
# Epoch 47/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0412 - val_loss: 0.0412 - learning_rate: 5.0000e-04
# Epoch 48/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0393 - val_loss: 0.0416 - learning_rate: 5.0000e-04
# Epoch 49/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0392 - val_loss: 0.0418 - learning_rate: 5.0000e-04
# Epoch 50/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0400 - val_loss: 0.0404 - learning_rate: 5.0000e-04
# Epoch 51/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0393 - val_loss: 0.0390 - learning_rate: 5.0000e-04
# Epoch 52/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0387 - val_loss: 0.0384 - learning_rate: 5.0000e-04
# Epoch 53/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0382 - val_loss: 0.0382 - learning_rate: 5.0000e-04
# Epoch 54/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0373 - val_loss: 0.0382 - learning_rate: 5.0000e-04
# Epoch 55/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0411 - val_loss: 0.0386 - learning_rate: 5.0000e-04
# Epoch 56/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0357 - val_loss: 0.0393 - learning_rate: 5.0000e-04
# Epoch 57/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0372 - val_loss: 0.0398 - learning_rate: 5.0000e-04
# Epoch 58/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0370 - val_loss: 0.0397 - learning_rate: 5.0000e-04
# Epoch 59/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0363 - val_loss: 0.0390 - learning_rate: 5.0000e-04
# Epoch 60/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0344 - val_loss: 0.0389 - learning_rate: 2.5000e-04
# Epoch 61/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0369 - val_loss: 0.0385 - learning_rate: 2.5000e-04
# Epoch 62/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0368 - val_loss: 0.0381 - learning_rate: 2.5000e-04
# Epoch 63/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0413 - val_loss: 0.0374 - learning_rate: 2.5000e-04
# Epoch 64/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0366 - val_loss: 0.0369 - learning_rate: 2.5000e-04
# Epoch 65/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0391 - val_loss: 0.0367 - learning_rate: 2.5000e-04
# Epoch 66/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0371 - val_loss: 0.0366 - learning_rate: 2.5000e-04
# Epoch 67/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0389 - val_loss: 0.0365 - learning_rate: 2.5000e-04
# Epoch 68/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0357 - val_loss: 0.0365 - learning_rate: 2.5000e-04
# Epoch 69/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0358 - val_loss: 0.0364 - learning_rate: 2.5000e-04
# Epoch 70/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0344 - val_loss: 0.0363 - learning_rate: 2.5000e-04
# Epoch 71/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0337 - val_loss: 0.0364 - learning_rate: 2.5000e-04
# Epoch 72/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0360 - val_loss: 0.0362 - learning_rate: 2.5000e-04
# Epoch 73/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0354 - val_loss: 0.0360 - learning_rate: 2.5000e-04
# Epoch 74/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0342 - val_loss: 0.0361 - learning_rate: 2.5000e-04
# Epoch 75/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0332 - val_loss: 0.0366 - learning_rate: 2.5000e-04
# Epoch 76/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0334 - val_loss: 0.0370 - learning_rate: 2.5000e-04
# Epoch 77/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0346 - val_loss: 0.0369 - learning_rate: 2.5000e-04
# Epoch 78/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0327 - val_loss: 0.0367 - learning_rate: 2.5000e-04
# Epoch 79/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0352 - val_loss: 0.0363 - learning_rate: 2.5000e-04
# Epoch 80/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0332 - val_loss: 0.0361 - learning_rate: 1.2500e-04
# Epoch 81/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0366 - val_loss: 0.0358 - learning_rate: 1.2500e-04
# Epoch 82/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0361 - val_loss: 0.0355 - learning_rate: 1.2500e-04
# Epoch 83/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0333 - val_loss: 0.0354 - learning_rate: 1.2500e-04
# Epoch 84/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0338 - val_loss: 0.0353 - learning_rate: 1.2500e-04
# Epoch 85/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0330 - val_loss: 0.0353 - learning_rate: 1.2500e-04
# Epoch 86/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0356 - val_loss: 0.0353 - learning_rate: 1.2500e-04
# Epoch 87/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0324 - val_loss: 0.0353 - learning_rate: 1.2500e-04
# Epoch 88/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0348 - val_loss: 0.0352 - learning_rate: 1.2500e-04
# Epoch 89/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0332 - val_loss: 0.0353 - learning_rate: 1.2500e-04
# Epoch 90/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0347 - val_loss: 0.0352 - learning_rate: 1.2500e-04
# Epoch 91/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0345 - val_loss: 0.0352 - learning_rate: 6.2500e-05
# Epoch 92/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0328 - val_loss: 0.0352 - learning_rate: 6.2500e-05
# Epoch 93/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0329 - val_loss: 0.0352 - learning_rate: 6.2500e-05
# Epoch 94/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0350 - val_loss: 0.0352 - learning_rate: 6.2500e-05
# Epoch 95/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0334 - val_loss: 0.0352 - learning_rate: 6.2500e-05
# Epoch 96/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0309 - val_loss: 0.0353 - learning_rate: 6.2500e-05
# Epoch 97/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0364 - val_loss: 0.0353 - learning_rate: 6.2500e-05
# Epoch 98/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0350 - val_loss: 0.0353 - learning_rate: 3.1250e-05
# Epoch 99/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0344 - val_loss: 0.0353 - learning_rate: 3.1250e-05
# Epoch 100/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0381 - val_loss: 0.0353 - learning_rate: 3.1250e-05
# Epoch 101/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0332 - val_loss: 0.0353 - learning_rate: 3.1250e-05
# Epoch 102/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0347 - val_loss: 0.0353 - learning_rate: 3.1250e-05
# Epoch 103/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0362 - val_loss: 0.0352 - learning_rate: 3.1250e-05
# Epoch 104/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0333 - val_loss: 0.0352 - learning_rate: 1.5625e-05
# Epoch 105/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0323 - val_loss: 0.0352 - learning_rate: 1.5625e-05
# Epoch 106/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0336 - val_loss: 0.0352 - learning_rate: 1.5625e-05

# %% [markdown]
# # 5. Plotting

# %%
plt.figure(figsize=(10,6))
plt.plot(history.history['loss'], label='Loss (Training MSE)', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss (Validation MSE)', color='red')
plt.title('Autoencoder Training History (Loss vs. Validation Loss)')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # 6. Save Model

# %%
path = os.path.join(output_dir, "squat_autoencoder.keras")
autoencoder.save(path)

# %% [markdown]
# save tfjs karena kami berencana menggunakan react.js untuk frontend

# %%
# tfjs_output = os.path.join(output_dir, "pushup_tfjs")
# tfjs.converters.save_keras_model(autoencoder, tfjs_output)

# %%
recon = autoencoder.predict(x_scaled, verbose=0)
train_mse_vals = np.mean(np.square(x_scaled - recon), axis=1)
np.save(os.path.join(output_dir, "squat_train_mse_stats.npy"), train_mse_vals)

# %% [markdown]
# # 7. Testing

# %%
test_video = "testsquat.mp4"

# %%
scaler_loaded = joblib.load(os.path.join(output_dir, "squat_scaler.pkl"))
autoencoder_loaded = tf.keras.models.load_model(os.path.join(output_dir, "squat_autoencoder.keras"))
train_mse_vals_loaded  = np.load(os.path.join(output_dir, "squat_train_mse_stats.npy"))

# %%
feat = extract_features_video(test_video)

# %%
if np.allclose(feat, 0):
    score = 5.0  
else:
    feat_scaled = scaler_loaded.transform(feat.reshape(1, -1))
    reconstruction = autoencoder_loaded.predict(feat_scaled, verbose=0)
    mse = np.mean(np.square(feat_scaled - reconstruction))
    low, high = np.percentile(train_mse_vals_loaded, [5, 95])
    max_mse = high * 3 
    
    if mse <= low:
        score = 100
    elif mse >= max_mse:
        score = 5
    else:
        score = 100 - 95 * (mse - low) / (max_mse - low)
    
    score = float(np.clip(score, 5, 100))

print(f"Score for {test_video}: {score:.2f}/100")
# Out:
# Score for testsquat.mp4: 70.15/100
